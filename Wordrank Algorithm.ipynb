# %% [markdown]
# # Wordrank Algorithm
#
# Basic wordrank algorithm for FOSL dataset.
# Currently only works for the English language. For other languages you will need to add/subtract things to the pruning step to fit that language's grammar.

# %%
import pandas as pd

# %%
# Import sample dataset
# I made the description all lowercase since case sensitivity introduces tons of bugs
df = pd.read_csv("Contacts From Web Confrences.csv")
df['description'] = df['description'].str.lower()
df
# Out:
#       firstname        lastname  \
# 0          Bill            Kemp
# 1         Boris       Goldstein
# 2         Billy        Barnwell
# 3         Irfan           Ahmad
# 4            JA      Colantonio
# 5         James         Santore
# 6           Ali  Khademhosseini
# 7   Anna Jamell         Siefken
# 8        Nicole         Lazzaro
# 9        Rhonda       Stevenson
# 10        Steve       Wilcenski
# 11          Dan         Richard
# 12         Matt         Colbert
# 13         Eric         Doherty
# 14        Reyad         Fezzani
# 15      Jeffrey            Arle
# 16         Dale            Amon
# 17          Tim       Brosnihan
# 18          Jeb          Linton
# 19       Pamela          Contag
# 20       Alexey      Melishchuk
# 21         Ryan            Tian
# 22      Zachary           Sadow
# 23         Jack            Bobo
# 24        Brian         Darmody
# 25         Mark     Modzelewski
#
#                                                 title  \
# 0                                                 CEO
# 1                                                 CEO
# 2                                       Founder & CEO
# 3   Executive Director, Interdisciplinary Initiatives
# 4      Program Manager, Innovation & Entrepreneurship
# 5                Director of Marketing & Social Media
# 6                                            Director
# 7   Executive Director, Wliton Scott Institute for...
# 8                                           President
# 9                                                 CEO
# 10                                                CEO
# 11                                          President
# 12                                                CEO
# 13                                          President
# 14                                                CEO
# 15                                                CEO
# 16                                                CEO
# 17                                 Executive Director
# 18        CTO, Partner Ecosystem & Cognitive Security
# 19                                                CEO
# 20                      Associate Director, Licensing
# 21                                Associate Professor
# 22                                                NaN
# 23                                                CEO
# 24                                 Executive Director
# 25           Strategy Consultant to Various Companies
#
#                                     organization  \
# 0                        United Space Structures
# 1                                     Grapheneca
# 2                           Climate Cure Capital
# 3                Grainger College of Engineering
# 4           National Renewable Energy Lab (NREL)
# 5                            Seventy Six Capital
# 6   Terasaki Institute for Biomedical Innovation
# 7                     Carnegie Mellon University
# 8                                      XEODesign
# 9                          Orbital Assembly Corp
# 10                                        BNNano
# 11                       Sports Engineering Inc.
# 12                        Spend Consciously Inc.
# 13                             Blink Science Inc
# 14                           Carbon Collect Inc.
# 15                               Intellihat Inc.
# 16                            Immortal Data Inc.
# 17                 MEMS & Sensors Industry Group
# 18                              IBM Watson Cloud
# 19                  BioEclipse Therapeutics Inc.
# 20                             Drexel University
# 21                        University of Arkansas
# 22                              KMX Technologies
# 23                                 Futurity Food
# 24      Association of University Research Parks
# 25                                           NaN
#
#                                           description
# 0   commercialization of space – buildings & struc...
# 1   graphene nanomaterials – applications in energ...
# 2   development of carbon negative technologies & ...
# 3   health innovation at the intersection of engin...
# 4   new technologies & opportunities to work with ...
# 5   trends & updates from games, sports & e-sports...
# 6   combining genomics, proteomics, metabolomics &...
# 7   breakthrough technologies to accelerate the tr...
# 8   making games that unlock human potential and i...
# 9                           building gravity in space
# 10  transforming and revitalizing industrial commo...
# 11  development and commercialization of injury pr...
# 12  social commerce – apps & web-based tools to he...
# 13  high tech, low cost, point of care testing & m...
# 14  mechanical trees, carbon collection & reuse, &...
# 15  wearable technology designed to slow the effec...
# 16  central nervous systems for aerospace ships & ...
# 17  opportunities & needs in american semiconducto...
# 18  applied deep learning & decentralized systems ...
# 19  precision immunotherapies to battle unmet heal...
# 20  licensing & startup opportunities from drexel ...
# 21  update on & opportunities to connect with univ...
# 22  membrane distillation technologies for treatme...
# 23  reflections on food, nutrition & agricultural ...
# 24  research parks as drivers of economic developm...
# 25  introduction of new company uzume & discussion...

# %%
# Join all descriptions so they form a block of text. Each description is separated with a space " "
text = " ".join(df.description)
text
# Out:
# 'commercialization of space – buildings & structures on the moon graphene nanomaterials – applications in energy storage, healthy buildings, and more development of carbon negative technologies & trading carbon credits health innovation at the intersection of engineering & medicine new technologies & opportunities to work with nrel trends & updates from games, sports & e-sports leading vc investment firm combining genomics, proteomics, metabolomics & other -omics to create true personalized healthcare breakthrough technologies to accelerate the transition to a sustainable, low-carbon energy future making games that unlock human potential and improve quality of life through play building gravity in space transforming and revitalizing industrial commodities development and commercialization of injury preventive athletic footwear, sports equipment and products for health and well-being social commerce – apps & web-based tools to help people to spend their money in accordance with their values, beliefs and priorities. high tech, low cost, point of care testing & medical passports to prevent disease transmission, speed up treatment, and keep life going mechanical trees, carbon collection & reuse, & scaling up solutions to remove co2 from the atmosphere wearable technology designed to slow the effects of cognitive decline due to natural aging. central nervous systems for aerospace ships & engines, and data opportunities & needs in american semiconductors, sensors & devices ecosystem applied deep learning & decentralized systems to address large market opportunities & challenges precision immunotherapies to battle unmet healthcare needs & battle virtually untreatable cancers  licensing & startup opportunities from drexel university innovation hub update on & opportunities to connect with university of arkansas i3r institute post 2020 investment from walmart foundation membrane distillation technologies for treatment and recovery of water & wastewater in various industrial markets reflections on food, nutrition & agricultural revolutions research parks as drivers of economic development across america and around the world introduction of new company uzume & discussion with ceo christiana thomas'

# %%
# Turn the block of text into a list of individual words
words = text.split()
words
# Out:
# ['commercialization',
#  'of',
#  'space',
#  '–',
#  'buildings',
#  '&',
#  'structures',
#  'on',
#  'the',
#  'moon',
#  'graphene',
#  'nanomaterials',
#  '–',
#  'applications',
#  'in',
#  'energy',
#  'storage,',
#  'healthy',
#  'buildings,',
#  'and',
#  'more',
#  'development',
#  'of',
#  'carbon',
#  'negative',
#  'technologies',
#  '&',
#  'trading',
#  'carbon',
#  'credits',
#  'health',
#  'innovation',
#  'at',
#  'the',
#  'intersection',
#  'of',
#  'engineering',
#  '&',
#  'medicine',
#  'new',
#  'technologies',
#  '&',
#  'opportunities',
#  'to',
#  'work',
#  'with',
#  'nrel',
#  'trends',
#  '&',
#  'updates',
#  'from',
#  'games,',
#  'sports',
#  '&',
#  'e-sports',
#  'leading',
#  'vc',
#  'investment',
#  'firm',
#  'combining',
#  'genomics,',
#  'proteomics,',
#  'metabolomics',
#  '&',
#  'other',
#  '-omics',
#  'to',
#  'create',
#  'true',
#  'personalized',
#  'healthcare',
#  'breakthrough',
#  'technologies',
#  'to',
#  'accelerate',
#  'the',
#  'transition',
#  'to',
#  'a',
#  'sustainable,',
#  'low-carbon',
#  'energy',
#  'future',
#  'making',
#  'games',
#  'that',
#  'unlock',
#  'human',
#  'potential',
#  'and',
#  'improve',
#  'quality',
#  'of',
#  'life',
#  'through',
#  'play',
#  'building',
#  'gravity',
#  'in',
#  'space',
#  'transforming',
#  'and',
#  'revitalizing',
#  'industrial',
#  'commodities',
#  'development',
#  'and',
#  'commercialization',
#  'of',
#  'injury',
#  'preventive',
#  'athletic',
#  'footwear,',
#  'sports',
#  'equipment',
#  'and',
#  'products',
#  'for',
#  'health',
#  'and',
#  'well-being',
#  'social',
#  'commerce',
#  '–',
#  'apps',
#  '&',
#  'web-based',
#  'tools',
#  'to',
#  'help',
#  'people',
#  'to',
#  'spend',
#  'their',
#  'money',
#  'in',
#  'accordance',
#  'with',
#  'their',
#  'values,',
#  'beliefs',
#  'and',
#  'priorities.',
#  'high',
#  'tech,',
#  'low',
#  'cost,',
#  'point',
#  'of',
#  'care',
#  'testing',
#  '&',
#  'medical',
#  'passports',
#  'to',
#  'prevent',
#  'disease',
#  'transmission,',
#  'speed',
#  'up',
#  'treatment,',
#  'and',
#  'keep',
#  'life',
#  'going',
#  'mechanical',
#  'trees,',
#  'carbon',
#  'collection',
#  '&',
#  'reuse,',
#  '&',
#  'scaling',
#  'up',
#  'solutions',
#  'to',
#  'remove',
#  'co2',
#  'from',
#  'the',
#  'atmosphere',
#  'wearable',
#  'technology',
#  'designed',
#  'to',
#  'slow',
#  'the',
#  'effects',
#  'of',
#  'cognitive',
#  'decline',
#  'due',
#  'to',
#  'natural',
#  'aging.',
#  'central',
#  'nervous',
#  'systems',
#  'for',
#  'aerospace',
#  'ships',
#  '&',
#  'engines,',
#  'and',
#  'data',
#  'opportunities',
#  '&',
#  'needs',
#  'in',
#  'american',
#  'semiconductors,',
#  'sensors',
#  '&',
#  'devices',
#  'ecosystem',
#  'applied',
#  'deep',
#  'learning',
#  '&',
#  'decentralized',
#  'systems',
#  'to',
#  'address',
#  'large',
#  'market',
#  'opportunities',
#  '&',
#  'challenges',
#  'precision',
#  'immunotherapies',
#  'to',
#  'battle',
#  'unmet',
#  'healthcare',
#  'needs',
#  '&',
#  'battle',
#  'virtually',
#  'untreatable',
#  'cancers',
#  'licensing',
#  '&',
#  'startup',
#  'opportunities',
#  'from',
#  'drexel',
#  'university',
#  'innovation',
#  'hub',
#  'update',
#  'on',
#  '&',
#  'opportunities',
#  'to',
#  'connect',
#  'with',
#  'university',
#  'of',
#  'arkansas',
#  'i3r',
#  'institute',
#  'post',
#  '2020',
#  'investment',
#  'from',
#  'walmart',
#  'foundation',
#  'membrane',
#  'distillation',
#  'technologies',
#  'for',
#  'treatment',
#  'and',
#  'recovery',
#  'of',
#  'water',
#  '&',
#  'wastewater',
#  'in',
#  'various',
#  'industrial',
#  'markets',
#  'reflections',
#  'on',
#  'food,',
#  'nutrition',
#  '&',
#  'agricultural',
#  'revolutions',
#  'research',
#  'parks',
#  'as',
#  'drivers',
#  'of',
#  'economic',
#  'development',
#  'across',
#  'america',
#  'and',
#  'around',
#  'the',
#  'world',
#  'introduction',
#  'of',
#  'new',
#  'company',
#  'uzume',
#  '&',
#  'discussion',
#  'with',
#  'ceo',
#  'christiana',
#  'thomas']

# %%
# Set up stopwords: a common group of words that are not meaningful and should be removed
# I import a bunch of predetermined stopwords from another module. Then I add some of my own
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
stopwords.update(['building', 'transforming', 'cost', 'commodities', 'revitalizing',\
                  'commercialization', 'industrial', 'development', 'technologies', 'opportunities',\
                 'innovation', 'new', 'investment', 'low', 'systems', 'needs', 'battle', '–', '&', '-omics', '2020'])

# %%
stopwords
# Out:
# {'&',
#  '-omics',
#  '2020',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'battle',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'building',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'commercialization',
#  'commodities',
#  'cost',
#  'could',
#  "couldn't",
#  'development',
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'industrial',
#  'innovation',
#  'into',
#  'investment',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'low',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'needs',
#  'new',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'opportunities',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'revitalizing',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'systems',
#  'technologies',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'transforming',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '–'}

# %%
# Prune stopwords from our list of words before sorting
words_ps = [x for x in words if x not in stopwords]

# %%
words_ps
# Out:
# ['space',
#  'buildings',
#  'structures',
#  'moon',
#  'graphene',
#  'nanomaterials',
#  'applications',
#  'energy',
#  'storage,',
#  'healthy',
#  'buildings,',
#  'carbon',
#  'negative',
#  'trading',
#  'carbon',
#  'credits',
#  'health',
#  'intersection',
#  'engineering',
#  'medicine',
#  'work',
#  'nrel',
#  'trends',
#  'updates',
#  'games,',
#  'sports',
#  'e-sports',
#  'leading',
#  'vc',
#  'firm',
#  'combining',
#  'genomics,',
#  'proteomics,',
#  'metabolomics',
#  'create',
#  'true',
#  'personalized',
#  'healthcare',
#  'breakthrough',
#  'accelerate',
#  'transition',
#  'sustainable,',
#  'low-carbon',
#  'energy',
#  'future',
#  'making',
#  'games',
#  'unlock',
#  'human',
#  'potential',
#  'improve',
#  'quality',
#  'life',
#  'play',
#  'gravity',
#  'space',
#  'injury',
#  'preventive',
#  'athletic',
#  'footwear,',
#  'sports',
#  'equipment',
#  'products',
#  'health',
#  'well-being',
#  'social',
#  'commerce',
#  'apps',
#  'web-based',
#  'tools',
#  'help',
#  'people',
#  'spend',
#  'money',
#  'accordance',
#  'values,',
#  'beliefs',
#  'priorities.',
#  'high',
#  'tech,',
#  'cost,',
#  'point',
#  'care',
#  'testing',
#  'medical',
#  'passports',
#  'prevent',
#  'disease',
#  'transmission,',
#  'speed',
#  'treatment,',
#  'keep',
#  'life',
#  'going',
#  'mechanical',
#  'trees,',
#  'carbon',
#  'collection',
#  'reuse,',
#  'scaling',
#  'solutions',
#  'remove',
#  'co2',
#  'atmosphere',
#  'wearable',
#  'technology',
#  'designed',
#  'slow',
#  'effects',
#  'cognitive',
#  'decline',
#  'due',
#  'natural',
#  'aging.',
#  'central',
#  'nervous',
#  'aerospace',
#  'ships',
#  'engines,',
#  'data',
#  'american',
#  'semiconductors,',
#  'sensors',
#  'devices',
#  'ecosystem',
#  'applied',
#  'deep',
#  'learning',
#  'decentralized',
#  'address',
#  'large',
#  'market',
#  'challenges',
#  'precision',
#  'immunotherapies',
#  'unmet',
#  'healthcare',
#  'virtually',
#  'untreatable',
#  'cancers',
#  'licensing',
#  'startup',
#  'drexel',
#  'university',
#  'hub',
#  'update',
#  'connect',
#  'university',
#  'arkansas',
#  'i3r',
#  'institute',
#  'post',
#  'walmart',
#  'foundation',
#  'membrane',
#  'distillation',
#  'treatment',
#  'recovery',
#  'water',
#  'wastewater',
#  'various',
#  'markets',
#  'reflections',
#  'food,',
#  'nutrition',
#  'agricultural',
#  'revolutions',
#  'research',
#  'parks',
#  'drivers',
#  'economic',
#  'across',
#  'america',
#  'around',
#  'world',
#  'introduction',
#  'company',
#  'uzume',
#  'discussion',
#  'ceo',
#  'christiana',
#  'thomas']

# %%
# Prune and sort words by frequency

# Create dictionary
d = {}
for word in words_ps:
    # Pruning
    # Prune off parentheses [] and ()
    if word.startswith('[') or word.startswith('('):
        word = word[1:]
    if word.endswith(']') or word.endswith(')'):
        word = word[:-1]
        
    # Prune off ending punctuation
    if word.endswith('.') or word.endswith(',') or word.endswith(';') or word.endswith(':'):
        word = word[:-1]
        
    # If word is already in dictionary, increase the value by 1
    # Otherwise add the word to dictionary with value 1
    if word in d:
        d[word] += 1
    else:
        d[word] = 1

# Order dictionary frequency in ascending order
# For this algorithm test I am only using one description group per person, so as the algorithm goes down the list
# it will replace the lower value key with a higher value one
d = dict(sorted(d.items(), key = lambda item: item[1]))

# %%
# Done
d
# Out:
# {'structures': 1,
#  'moon': 1,
#  'graphene': 1,
#  'nanomaterials': 1,
#  'applications': 1,
#  'storage': 1,
#  'healthy': 1,
#  'negative': 1,
#  'trading': 1,
#  'credits': 1,
#  'intersection': 1,
#  'engineering': 1,
#  'medicine': 1,
#  'work': 1,
#  'nrel': 1,
#  'trends': 1,
#  'updates': 1,
#  'e-sports': 1,
#  'leading': 1,
#  'vc': 1,
#  'firm': 1,
#  'combining': 1,
#  'genomics': 1,
#  'proteomics': 1,
#  'metabolomics': 1,
#  'create': 1,
#  'true': 1,
#  'personalized': 1,
#  'breakthrough': 1,
#  'accelerate': 1,
#  'transition': 1,
#  'sustainable': 1,
#  'low-carbon': 1,
#  'future': 1,
#  'making': 1,
#  'unlock': 1,
#  'human': 1,
#  'potential': 1,
#  'improve': 1,
#  'quality': 1,
#  'play': 1,
#  'gravity': 1,
#  'injury': 1,
#  'preventive': 1,
#  'athletic': 1,
#  'footwear': 1,
#  'equipment': 1,
#  'products': 1,
#  'well-being': 1,
#  'social': 1,
#  'commerce': 1,
#  'apps': 1,
#  'web-based': 1,
#  'tools': 1,
#  'help': 1,
#  'people': 1,
#  'spend': 1,
#  'money': 1,
#  'accordance': 1,
#  'values': 1,
#  'beliefs': 1,
#  'priorities': 1,
#  'high': 1,
#  'tech': 1,
#  'cost': 1,
#  'point': 1,
#  'care': 1,
#  'testing': 1,
#  'medical': 1,
#  'passports': 1,
#  'prevent': 1,
#  'disease': 1,
#  'transmission': 1,
#  'speed': 1,
#  'keep': 1,
#  'going': 1,
#  'mechanical': 1,
#  'trees': 1,
#  'collection': 1,
#  'reuse': 1,
#  'scaling': 1,
#  'solutions': 1,
#  'remove': 1,
#  'co2': 1,
#  'atmosphere': 1,
#  'wearable': 1,
#  'technology': 1,
#  'designed': 1,
#  'slow': 1,
#  'effects': 1,
#  'cognitive': 1,
#  'decline': 1,
#  'due': 1,
#  'natural': 1,
#  'aging': 1,
#  'central': 1,
#  'nervous': 1,
#  'aerospace': 1,
#  'ships': 1,
#  'engines': 1,
#  'data': 1,
#  'american': 1,
#  'semiconductors': 1,
#  'sensors': 1,
#  'devices': 1,
#  'ecosystem': 1,
#  'applied': 1,
#  'deep': 1,
#  'learning': 1,
#  'decentralized': 1,
#  'address': 1,
#  'large': 1,
#  'market': 1,
#  'challenges': 1,
#  'precision': 1,
#  'immunotherapies': 1,
#  'unmet': 1,
#  'virtually': 1,
#  'untreatable': 1,
#  'cancers': 1,
#  'licensing': 1,
#  'startup': 1,
#  'drexel': 1,
#  'hub': 1,
#  'update': 1,
#  'connect': 1,
#  'arkansas': 1,
#  'i3r': 1,
#  'institute': 1,
#  'post': 1,
#  'walmart': 1,
#  'foundation': 1,
#  'membrane': 1,
#  'distillation': 1,
#  'recovery': 1,
#  'water': 1,
#  'wastewater': 1,
#  'various': 1,
#  'markets': 1,
#  'reflections': 1,
#  'food': 1,
#  'nutrition': 1,
#  'agricultural': 1,
#  'revolutions': 1,
#  'research': 1,
#  'parks': 1,
#  'drivers': 1,
#  'economic': 1,
#  'across': 1,
#  'america': 1,
#  'around': 1,
#  'world': 1,
#  'introduction': 1,
#  'company': 1,
#  'uzume': 1,
#  'discussion': 1,
#  'ceo': 1,
#  'christiana': 1,
#  'thomas': 1,
#  'space': 2,
#  'buildings': 2,
#  'energy': 2,
#  'health': 2,
#  'games': 2,
#  'sports': 2,
#  'healthcare': 2,
#  'life': 2,
#  'treatment': 2,
#  'university': 2,
#  'carbon': 3}

# %% [markdown]
# # Using Wordrank to Create Groups

# %%
# Create description group
# This method is very slow, for large lists it will be unfeasable. Will need to replace with something more
# efficient down the line
for i in range(len(df)):
    for j in range(len(d)):
        df.loc[df['description'].str.contains(list(d.keys())[j]), 'dgroup'] = list(d.keys())[j]

# %%
# Sort df by description group, alphabetically
df_sort = df.sort_values('dgroup').reset_index()

# Done
df_sort
# Out:
#     index    firstname        lastname  \
# 0      15      Jeffrey            Arle
# 1      17          Tim       Brosnihan
# 2       0         Bill            Kemp
# 3       2        Billy        Barnwell
# 4      14        Reyad         Fezzani
# 5       7  Anna Jamell         Siefken
# 6      18          Jeb          Linton
# 7       1        Boris       Goldstein
# 8       3        Irfan           Ahmad
# 9      19       Pamela          Contag
# 10      6          Ali  Khademhosseini
# 11      8       Nicole         Lazzaro
# 12     12         Matt         Colbert
# 13     23         Jack            Bobo
# 14     16         Dale            Amon
# 15      9       Rhonda       Stevenson
# 16     11          Dan         Richard
# 17      5        James         Santore
# 18      4           JA      Colantonio
# 19     25         Mark     Modzelewski
# 20     22      Zachary           Sadow
# 21     13         Eric         Doherty
# 22     21         Ryan            Tian
# 23     20       Alexey      Melishchuk
# 24     24        Brian         Darmody
# 25     10        Steve       Wilcenski
#
#                                                 title  \
# 0                                                 CEO
# 1                                  Executive Director
# 2                                                 CEO
# 3                                       Founder & CEO
# 4                                                 CEO
# 5   Executive Director, Wliton Scott Institute for...
# 6         CTO, Partner Ecosystem & Cognitive Security
# 7                                                 CEO
# 8   Executive Director, Interdisciplinary Initiatives
# 9                                                 CEO
# 10                                           Director
# 11                                          President
# 12                                                CEO
# 13                                                CEO
# 14                                                CEO
# 15                                                CEO
# 16                                          President
# 17               Director of Marketing & Social Media
# 18     Program Manager, Innovation & Entrepreneurship
# 19           Strategy Consultant to Various Companies
# 20                                                NaN
# 21                                          President
# 22                                Associate Professor
# 23                      Associate Director, Licensing
# 24                                 Executive Director
# 25                                                CEO
#
#                                     organization  \
# 0                                Intellihat Inc.
# 1                  MEMS & Sensors Industry Group
# 2                        United Space Structures
# 3                           Climate Cure Capital
# 4                            Carbon Collect Inc.
# 5                     Carnegie Mellon University
# 6                               IBM Watson Cloud
# 7                                     Grapheneca
# 8                Grainger College of Engineering
# 9                   BioEclipse Therapeutics Inc.
# 10  Terasaki Institute for Biomedical Innovation
# 11                                     XEODesign
# 12                        Spend Consciously Inc.
# 13                                 Futurity Food
# 14                            Immortal Data Inc.
# 15                         Orbital Assembly Corp
# 16                       Sports Engineering Inc.
# 17                           Seventy Six Capital
# 18          National Renewable Energy Lab (NREL)
# 19                                           NaN
# 20                              KMX Technologies
# 21                             Blink Science Inc
# 22                        University of Arkansas
# 23                             Drexel University
# 24      Association of University Research Parks
# 25                                        BNNano
#
#                                           description       dgroup
# 0   wearable technology designed to slow the effec...        aging
# 1   opportunities & needs in american semiconducto...      america
# 2   commercialization of space – buildings & struc...    buildings
# 3   development of carbon negative technologies & ...       carbon
# 4   mechanical trees, carbon collection & reuse, &...       carbon
# 5   breakthrough technologies to accelerate the tr...       carbon
# 6   applied deep learning & decentralized systems ...   challenges
# 7   graphene nanomaterials – applications in energ...       health
# 8   health innovation at the intersection of engin...       health
# 9   precision immunotherapies to battle unmet heal...   healthcare
# 10  combining genomics, proteomics, metabolomics &...   healthcare
# 11  making games that unlock human potential and i...         life
# 12  social commerce – apps & web-based tools to he...   priorities
# 13  reflections on food, nutrition & agricultural ...  revolutions
# 14  central nervous systems for aerospace ships & ...        space
# 15                          building gravity in space        space
# 16  development and commercialization of injury pr...       sports
# 17  trends & updates from games, sports & e-sports...       sports
# 18  new technologies & opportunities to work with ...         tech
# 19  introduction of new company uzume & discussion...       thomas
# 20  membrane distillation technologies for treatme...    treatment
# 21  high tech, low cost, point of care testing & m...    treatment
# 22  update on & opportunities to connect with univ...   university
# 23  licensing & startup opportunities from drexel ...   university
# 24  research parks as drivers of economic developm...        world
# 25  transforming and revitalizing industrial commo...          NaN

# %%
# Example: Find people in description group "health"
df[df.dgroup == 'health']
# Out:
#   firstname   lastname                                              title  \
# 1     Boris  Goldstein                                                CEO
# 3     Irfan      Ahmad  Executive Director, Interdisciplinary Initiatives
#
#                       organization  \
# 1                       Grapheneca
# 3  Grainger College of Engineering
#
#                                          description  dgroup
# 1  graphene nanomaterials – applications in energ...  health
# 3  health innovation at the intersection of engin...  health
